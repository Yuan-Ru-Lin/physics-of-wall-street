# %%
import matplotlib as mpl
# mpl.use('TkAgg')
mpl.rcParams.update({
    'figure.figsize': (4, 4),
    'figure.dpi': 150,
    'font.sans-serif': ['Microsoft JhengHei'],
})

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
def gaussian(x, mean, sigma):
    return np.exp(-0.5 * ((x-mean) / sigma)**2) / np.sqrt(2*np.pi) / sigma

# %%
# %matplotlib notebook

fig, ax = plt.subplots()

fig.suptitle("巴楔利耶的股價模型——常態分佈曲線")
ax.get_yaxis().set_label_text("機率分佈函數")
ax.get_yaxis().set_ticks([])
ax.get_xaxis().set_label_text("股價")

x = np.linspace(0, 300, 1000)
line, = ax.plot(x, gaussian(x, mean=100, sigma=10))

def animate(i):
    line.set_ydata(gaussian(x, mean=100, sigma=10 + 1 * i))
    line.set_label(f"第 {i} 年")
    return [line, plt.legend()]


ani = animation.FuncAnimation(fig=fig, func=animate,
                              frames=range(1, 21),
                              interval=200, blit=True,
#                               repeat=False,
                              repeat_delay=1000,
                             )

# ani.save("movie.gif", writer="imagemagick")
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
